# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/robsmith/.pyenv/versions/3.12.6/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/robsmith/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/robsmith/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/robsmith/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/robsmith/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/robsmith/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/robsmith/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/robsmith/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/robsmith/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/robsmith/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/robsmith/.pyenv/versions/3.12.6/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# %%
# Function to generate Fibonacci numbers
def fibonacci(n):
    fib_sequence = [0, 1]
    while len(fib_sequence) < n:
        fib_sequence.append(fib_sequence[-1] + fib_sequence[-2])
    return fib_sequence[:n]

# %%
# Generate the first 10 Fibonacci numbers
fib_numbers = fibonacci(10)

# %%
# Plot the Fibonacci numbers on a bar chart
plt.bar(range(1, 11), fib_numbers)
plt.xlabel('Position')
plt.ylabel('Fibonacci Number')
plt.title('First 10 Fibonacci Numbers')
plt.show()
